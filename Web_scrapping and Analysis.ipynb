# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 10 #10
page_size = 100 #100

reviews = []
aircraft = []
seat_type = []
route = []
recommended = []
df = pd.DataFrame()

# for i in range(1, pages + 1):
for i in range(1, pages + 1):
    
    rating = []
    category = []

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
        
    for para2 in parsed_content.find_all("div", {"class" : "review-stats"}):
        for para3 in para2.find_all('td',{'class' : 'review-value'}):
            rating.append(para3.get_text())
        recomend = rating[-1]
        rating = rating[:-1]
        
        for para4 in para2.find_all('td',{'class' : 'review-rating-stars stars'}):
            para5 = len(para4.find_all('span', {'class' : 'star fill'}))
            rating.append(para5)
        rating.append(recomend)
        #print(rating)
        
        for para6 in para2.find_all('td',{'class' : 'review-rating-header'}):
            category.append(para6.get_text())
            
        #print(category)
        # Create the records from both list, using zip and dict calls.

        # Build the dataframe from the dictionary.
        data_dict = pd.DataFrame([rating], columns=category)
        df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
        #print(df)
        rating = []
        category = []
        
    print(f"   ---> {len(reviews)} total reviews")

df["reviews"] = reviews
# Out:
# Scraping page 1
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
#    ---> 100 total reviews
# Scraping page 2
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# ...
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
#    ---> 1000 total reviews
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\456219825.py:52: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(data_dict, ignore_index=True).reset_index(drop=True)

# %%
df
# Out:
#        Aircraft Type Of Traveller        Seat Type  \
# 0          A321    Family Leisure   Business Class
# 1           NaN    Family Leisure    Economy Class
# 2           NaN    Family Leisure    Economy Class
# 3           NaN    Couple Leisure  Premium Economy
# 4           NaN    Couple Leisure    Economy Class
# ..          ...               ...              ...
# 995        A319    Couple Leisure   Business Class
# 996        A320    Couple Leisure   Business Class
# 997        A380    Couple Leisure  Premium Economy
# 998         NaN    Family Leisure    Economy Class
# 999  Boeing 777      Solo Leisure  Premium Economy
#
#                                          Route      Date Flown  Seat Comfort  \
# 0                             Madrid to London       July 2023           1.0
# 1                            Rhodes to Gatwick       July 2023           2.0
# 2                          Barcelona to London       July 2023           1.0
# 3          Inverness to Los Angeles via London   November 2022           NaN
# 4             London City Airport to Frankfurt       July 2023           3.0
# ..                                         ...             ...           ...
# 995  Los Angeles to Leeds via London Heathrow        June 2018           4.0
# 996                         Brindisi to London  September 2018           1.0
# 997                          Chicago to London  September 2018           1.0
# 998                           Berlin to London  September 2018           2.0
# 999                          Riyadh to London      August 2018           5.0
#
#      Cabin Staff Service  Ground Service  Value For Money Recommended  \
# 0                    1.0             1.0                1          no
# 1                    3.0             1.0                2          no
# 2                    4.0             1.0                1          no
# 3                    NaN             NaN                1          no
# 4                    3.0             1.0                1          no
# ..                   ...             ...              ...         ...
# 995                  4.0             1.0                3          no
# 996                  2.0             1.0                2          no
# 997                  1.0             3.0                1          no
# 998                  2.0             2.0                1          no
# 999                  5.0             3.0                5         yes
#
#      Food & Beverages  Inflight Entertainment  Wifi & Connectivity  \
# 0                 NaN                     NaN                  NaN
# 1                 1.0                     1.0                  1.0
# 2                 1.0                     1.0                  1.0
# 3                 NaN                     NaN                  NaN
# 4                 NaN                     NaN                  NaN
# ..                ...                     ...                  ...
# 995               4.0                     3.0                  2.0
# 996               2.0                     NaN                  NaN
# 997               1.0                     1.0                  NaN
# 998               NaN                     NaN                  NaN
# 999               5.0                     4.0                  NaN
#
#                                                reviews
# 0    ✅ Trip Verified | An airline that lives in the...
# 1    ✅ Trip Verified |  Check-in Desk rude and dism...
# 2    ✅ Trip Verified | I chose British Airways espe...
# 3    Not Verified | I booked Premium Economy from I...
# 4    ✅ Trip Verified | A simple story with an unfor...
# ..                                                 ...
# 995  ✅ Trip Verified | We flew from Los Angeles to ...
# 996  ✅ Trip Verified |  Brindisi to London. Flying ...
# 997  ✅ Trip Verified |  Chicago to London. I have f...
# 998  ✅ Trip Verified |  Berlin to London. It was a ...
# 999  ✅ Trip Verified |  British Airways is my favor...
#
# [1000 rows x 14 columns]

# %%
df.to_csv("BA_reviews.csv", index=False)

# %%
df = pd.read_csv('BA_reviews.csv')

# %%
remove_text = ['✅ Trip Verified', 'Not Verified |']

for i in range(len(df['reviews'])):
    for j in remove_text:
        if j in df['reviews'][i]:
            df['reviews'] = df['reviews'].str.replace(j,'')
# Out:
# C:\Users\Sourabh.yadav\AppData\Local\Temp\ipykernel_8048\422421243.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['reviews'] = df['reviews'].str.replace(j,'')

# %%
df
# Out:
#        Aircraft Type Of Traveller        Seat Type  \
# 0          A321    Family Leisure   Business Class
# 1           NaN    Family Leisure    Economy Class
# 2           NaN    Family Leisure    Economy Class
# 3           NaN    Couple Leisure  Premium Economy
# 4           NaN    Couple Leisure    Economy Class
# ..          ...               ...              ...
# 995        A319    Couple Leisure   Business Class
# 996        A320    Couple Leisure   Business Class
# 997        A380    Couple Leisure  Premium Economy
# 998         NaN    Family Leisure    Economy Class
# 999  Boeing 777      Solo Leisure  Premium Economy
#
#                                          Route      Date Flown  Seat Comfort  \
# 0                             Madrid to London       July 2023           1.0
# 1                            Rhodes to Gatwick       July 2023           2.0
# 2                          Barcelona to London       July 2023           1.0
# 3          Inverness to Los Angeles via London   November 2022           NaN
# 4             London City Airport to Frankfurt       July 2023           3.0
# ..                                         ...             ...           ...
# 995  Los Angeles to Leeds via London Heathrow        June 2018           4.0
# 996                         Brindisi to London  September 2018           1.0
# 997                          Chicago to London  September 2018           1.0
# 998                           Berlin to London  September 2018           2.0
# 999                          Riyadh to London      August 2018           5.0
#
#      Cabin Staff Service  Ground Service  Value For Money Recommended  \
# 0                    1.0             1.0                1          no
# 1                    3.0             1.0                2          no
# 2                    4.0             1.0                1          no
# 3                    NaN             NaN                1          no
# 4                    3.0             1.0                1          no
# ..                   ...             ...              ...         ...
# 995                  4.0             1.0                3          no
# 996                  2.0             1.0                2          no
# 997                  1.0             3.0                1          no
# 998                  2.0             2.0                1          no
# 999                  5.0             3.0                5         yes
#
#      Food & Beverages  Inflight Entertainment  Wifi & Connectivity  \
# 0                 NaN                     NaN                  NaN
# 1                 1.0                     1.0                  1.0
# 2                 1.0                     1.0                  1.0
# 3                 NaN                     NaN                  NaN
# 4                 NaN                     NaN                  NaN
# ..                ...                     ...                  ...
# 995               4.0                     3.0                  2.0
# 996               2.0                     NaN                  NaN
# 997               1.0                     1.0                  NaN
# 998               NaN                     NaN                  NaN
# 999               5.0                     4.0                  NaN
#
#                                                reviews
# 0     | An airline that lives in their past glory a...
# 1     |  Check-in Desk rude and dismissive. Flight ...
# 2     | I chose British Airways especially because ...
# 3    | I booked Premium Economy from INV to LAX (vi...
# 4     | A simple story with an unfortunate outcome ...
# ..                                                 ...
# 995   | We flew from Los Angeles to Leeds Bradford ...
# 996   |  Brindisi to London. Flying from any airpor...
# 997   |  Chicago to London. I have flown long haul ...
# 998   |  Berlin to London. It was a connecting flig...
# 999   |  British Airways is my favorite airline. Bo...
#
# [1000 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Aircraft                552 non-null    object
#  1   Type Of Traveller       999 non-null    object
#  2   Seat Type               1000 non-null   object
#  3   Route                   997 non-null    object
#  4   Date Flown              1000 non-null   object
#  5   Seat Comfort            918 non-null    float64
#  6   Cabin Staff Service     912 non-null    float64
#  7   Ground Service          945 non-null    float64
#  8   Value For Money         1000 non-null   int64
#  9   Recommended             1000 non-null   object
#  10  Food & Beverages        793 non-null    float64
#  11  Inflight Entertainment  548 non-null    float64
#  12  Wifi & Connectivity     278 non-null    float64
#  13  reviews                 1000 non-null   object
# dtypes: float64(6), int64(1), object(7)
# memory usage: 109.5+ KB

# %% [markdown]
# # Analysis of Data

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
review_word = []

for i in df['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %% [markdown]
# From the wordcloud above, we can see the key of topics in customer review are flight, seat , service and time. showing that people are actively talking about their experience on the plane and the staff.

# %% [markdown]
# # Satisfaction of customer

# %%
soc = df.groupby('Recommended')['reviews'].count().reset_index()
plt.pie(soc['reviews'], labels = soc['Recommended'], autopct='%.2f%%',colors = sns.color_palette('pastel'),
          wedgeprops={"edgecolor":"k"},)
plt.legend()
plt.show()

# %% [markdown]
# From the pie chart above, we know that 63.3% of passengers are dissatisfied with British Airways services. let's breakdown the data to found what make passengers dissatisfied :

# %% [markdown]
# # View rating of BA service by passenger that dissatisfied with British Airways

# %%
df_soc = df[df['Recommended'] == 'no']
df_soc.describe()
# Out:
#        Seat Comfort  Cabin Staff Service  Ground Service  Value For Money  \
# count    578.000000           572.000000      604.000000       658.000000
# mean       2.096886             2.419580        1.902318         1.559271
# std        1.097164             1.316273        1.210263         0.845967
# min        1.000000             1.000000        1.000000         1.000000
# 25%        1.000000             1.000000        1.000000         1.000000
# 50%        2.000000             2.000000        1.000000         1.000000
# 75%        3.000000             3.000000        3.000000         2.000000
# max        5.000000             5.000000        5.000000         5.000000
#
#        Food & Beverages  Inflight Entertainment  Wifi & Connectivity
# count        476.000000              333.000000           172.000000
# mean           1.871849                2.132132             1.482558
# std            1.065421                1.224974             0.958031
# min            1.000000                1.000000             1.000000
# 25%            1.000000                1.000000             1.000000
# 50%            1.000000                2.000000             1.000000
# 75%            3.000000                3.000000             1.250000
# max            5.000000                5.000000             5.000000

# %% [markdown]
# # Analysis food on airways

# %%
data = df_soc[df_soc['reviews'].str.contains('food | drink')]
data['reviews'].to_csv('test.csv')

# %%
review_word = []

for i in data['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %% [markdown]
# I analyse the test.csv file, and get information that :
#
# Time to deliver the order is too long
#
# For free catering just bottle of water and a packet of crisps
#
# Minimal selection of food items for purchase.

# %% [markdown]
# # Analysis value for money

# %%
data = df_soc[df_soc['reviews'].str.contains('money | refund & value')]
data['reviews'].to_csv('test2.csv')

# %%
review_word = []

for i in data['reviews'] :
    a = i.split(' ')
    for x in a:
        review_word.append(x)
        
unique_string = (" ").join(review_word)

wc = WordCloud(width = 1000, height = 450, background_color = 'white').generate(unique_string)
plt.figure(figsize=(15,8))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %% [markdown]
# what I get from analysing the data :
#
# The refund take a lot of time
#
# Forced to use of vouchers however it was useless
#
# Long delay time
